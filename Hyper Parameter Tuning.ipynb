# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
data = load_breast_cancer()

# %%
df = pd.DataFrame(data.data, columns = data.feature_names)
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
df['label'] = data.target
df['label']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: label, Length: 569, dtype: int32

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  label
# 0                  0.2654          0.4601                  0.11890      0
# 1                  0.1860          0.2750                  0.08902      0
# 2                  0.2430          0.3613                  0.08758      0
# 3                  0.2575          0.6638                  0.17300      0
# 4                  0.1625          0.2364                  0.07678      0
# ..                    ...             ...                      ...    ...
# 564                0.2216          0.2060                  0.07115      0
# 565                0.1628          0.2572                  0.06637      0
# 566                0.1418          0.2218                  0.07820      0
# 567                0.2650          0.4087                  0.12400      0
# 568                0.0000          0.2871                  0.07039      1
#
# [569 rows x 31 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# %%
param_dist = {"n_estimators": range(90,101),
              "max_depth": [3, None],
              "max_features": range(1, 11),
              "min_samples_split": range(2, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# %%
rand_search = RandomizedSearchCV(clf, param_distributions=param_dist, n_iter=10, cv=5)

# %%
x = df.iloc[:,:-1]
y = df.iloc[:, -1]

# %%
rand_search.fit(x,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, None],
#                                         'max_features': range(1, 11),
#                                         'min_samples_split': range(2, 11),
#                                         'n_estimators': range(90, 101)})

# %%
rand_search.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=False, max_features=2, min_samples_split=9)

# %%
rand_search.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 9,
#  'max_features': 2,
#  'max_depth': None,
#  'criterion': 'gini',
#  'bootstrap': False}

# %%
rand_search.best_score_
# Out:
# 0.9666200900481291

# %%
rand_search.cv_results_
# Out:
# {'mean_fit_time': array([0.17606959, 0.12959886, 0.2064002 , 0.15200534, 0.12319474,
#         0.11520891, 0.29459085, 0.27519917, 0.14400215, 0.14560041]),
#  'std_fit_time': array([2.43740627e-02, 3.20017669e-03, 3.29464260e-02, 1.97842030e-05,
#         6.40283438e-03, 3.91942013e-03, 2.85683450e-02, 1.48378865e-02,
#         8.76799895e-03, 3.20119872e-03]),
#  'mean_score_time': array([0.00923319, 0.00799894, 0.00799966, 0.00799456, 0.0079999 ,
#         0.00959644, 0.00996475, 0.01279545, 0.00800271, 0.00800004]),
#  'std_score_time': array([3.46021410e-03, 1.65868064e-06, 7.68876815e-07, 1.04585076e-05,
#         5.00111031e-07, 3.20180009e-03, 7.26670550e-03, 6.39045431e-03,
#         5.04501826e-06, 7.62939453e-07]),
#  'param_n_estimators': masked_array(data=[100, 99, 90, 90, 95, 100, 100, 100, 93, 96],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[4, 5, 8, 7, 5, 9, 3, 6, 6, 8],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[9, 5, 6, 7, 3, 2, 9, 9, 7, 4],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[3, 3, None, None, 3, None, None, None, 3, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['gini', 'gini', 'entropy', 'gini', 'gini', 'gini',
#                     'entropy', 'entropy', 'gini', 'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_bootstrap': masked_array(data=[True, False, False, True, True, False, False, False,
#                     True, True],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_estimators': 100,
#    'min_samples_split': 4,
#    'max_features': 9,
#    'max_depth': 3,
#    'criterion': 'gini',
#    'bootstrap': True},
#   {'n_estimators': 99,
#    'min_samples_split': 5,
#    'max_features': 5,
#    'max_depth': 3,
#    'criterion': 'gini',
#    'bootstrap': False},
#   {'n_estimators': 90,
#    'min_samples_split': 8,
#    'max_features': 6,
#    'max_depth': None,
#    'criterion': 'entropy',
#    'bootstrap': False},
#   {'n_estimators': 90,
#    'min_samples_split': 7,
#    'max_features': 7,
#    'max_depth': None,
#    'criterion': 'gini',
#    'bootstrap': True},
#   {'n_estimators': 95,
#    'min_samples_split': 5,
#    'max_features': 3,
#    'max_depth': 3,
#    'criterion': 'gini',
#    'bootstrap': True},
#   {'n_estimators': 100,
#    'min_samples_split': 9,
#    'max_features': 2,
#    'max_depth': None,
#    'criterion': 'gini',
#    'bootstrap': False},
#   {'n_estimators': 100,
#    'min_samples_split': 3,
#    'max_features': 9,
#    'max_depth': None,
#    'criterion': 'entropy',
#    'bootstrap': False},
#   {'n_estimators': 100,
#    'min_samples_split': 6,
#    'max_features': 9,
#    'max_depth': None,
#    'criterion': 'entropy',
#    'bootstrap': False},
#   {'n_estimators': 93,
#    'min_samples_split': 6,
#    'max_features': 7,
#    'max_depth': 3,
#    'criterion': 'gini',
#    'bootstrap': True},
#   {'n_estimators': 96,
#    'min_samples_split': 8,
#    'max_features': 4,
#    'max_depth': 3,
#    'criterion': 'entropy',
#    'bootstrap': True}],
#  'split0_test_score': array([0.9122807 , 0.92982456, 0.92982456, 0.92105263, 0.92105263,
#         0.94736842, 0.94736842, 0.94736842, 0.93859649, 0.92982456]),
#  'split1_test_score': array([0.92982456, 0.93859649, 0.95614035, 0.94736842, 0.92982456,
#         0.95614035, 0.93859649, 0.94736842, 0.92982456, 0.93859649]),
#  'split2_test_score': array([0.98245614, 0.97368421, 0.98245614, 0.98245614, 0.98245614,
#         0.98245614, 0.98245614, 0.97368421, 0.97368421, 0.97368421]),
#  'split3_test_score': array([0.95614035, 0.96491228, 0.97368421, 0.96491228, 0.97368421,
#         0.97368421, 0.97368421, 0.97368421, 0.96491228, 0.96491228]),
#  'split4_test_score': array([0.96460177, 0.96460177, 0.97345133, 0.97345133, 0.96460177,
#         0.97345133, 0.98230088, 0.98230088, 0.96460177, 0.96460177]),
#  'mean_test_score': array([0.9490607 , 0.95432386, 0.96311132, 0.95784816, 0.95432386,
#         0.96662009, 0.96488123, 0.96488123, 0.95432386, 0.95432386]),
#  'std_test_score': array([0.02501879, 0.01697138, 0.01870576, 0.02173775, 0.02440932,
#         0.01286701, 0.01837063, 0.01464122, 0.01697138, 0.01697138]),
#  'rank_test_score': array([10,  6,  4,  5,  6,  1,  2,  2,  6,  6])}

# %%
param_grid = {"n_estimators": [80, 100, 120],
              "max_depth": [3, None],
              "max_features": [1, 3, 10],
              "min_samples_split": [2, 3, 10],
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

clf = RandomForestClassifier()
grid_search = GridSearchCV(clf, param_grid=param_grid, cv=5)
grid_search.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, None], 'max_features': [1, 3, 10],
#                          'min_samples_split': [2, 3, 10],
#                          'n_estimators': [80, 100, 120]})

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 10,
#  'min_samples_split': 2,
#  'n_estimators': 80}

# %%
grid_search.score
# Out:
# <bound method BaseSearchCV.score of GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, None], 'max_features': [1, 3, 10],
#                          'min_samples_split': [2, 3, 10],
#                          'n_estimators': [80, 100, 120]})>

# %%
grid_search.best_score_
# Out:
# 0.9718987734823784
